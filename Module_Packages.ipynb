# %%
import os

# %%
f=open('/content/drive/MyDrive/Colab Notebooks/module.py','w')

# %%
f.close()

# %%
import module

# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import module

# %%
module.test(1,2)
# Out:
# 3

# %%
module.test1(2,6)
# Out:
# 12

# %%
from module import test2

# %%
test2(4,5)
# Out:
# 1.25

# %%
from module import *
#imports every function avilable in module

# %%
test(1,6)
# Out:
# 7

# %%
test1(6,8)
# Out:
# 48

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %%
open('module2.py','w')
# Out:
# <_io.TextIOWrapper name='module2.py' mode='w' encoding='UTF-8'>

# %%
import module2

# %%
module2.getgreeting()
# Out:
# 'HI'

# %%
module2.get_course()
# Out:
# ['data science', 'AI', 'Ml', 'DL']

# %% [markdown]
# 1St class OOPS

# %%
cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import mydict

# %%
mydict.diction
# Out:
# mydict.diction

# %%
d = mydict.diction({5:'faf','kjf':'jffbf'})

# %%
d.dic_keys()
# Out:
# [5, 'kjf']

# %%
from mydict import diction

# %%
d=diction({'bsdu':'fjhvn','fuffb':5644})

# %%
d.dic_values()
# Out:
# ['fjhvn', 5644]
