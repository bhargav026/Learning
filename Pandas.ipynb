# %% [markdown]
#     pandas is lib which is file handling lib.
#     only for structured data, for non structred data normal file operaions  or any other methods

# %%
import pandas as pd

# %%
pd.read_csv('test.csv')
# Out:
#        name            emailid    address  pincode  sirname
# 0   bhargva  bhargav@gmail.com      amity   535126  killada
# 1     krish     krish@iisc.com  bangalore   560012     sudh
# 2  sudanshu     sudh@yahoo.com  bangalore   560013    krish

# %%
df = pd.read_csv('test.csv',encoding_errors='ignore')

# %% [markdown]
#     The above table is called data frame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#     padndas automatically considers the 1st row as columnn name

# %%
pd.read_csv('test.csv', header = None)
# Out:
#           0                  1          2        3        4
# 0      name            emailid    address  pincode  sirname
# 1   bhargva  bhargav@gmail.com      amity   535126  killada
# 2     krish     krish@iisc.com  bangalore   560012     sudh
# 3  sudanshu     sudh@yahoo.com  bangalore   560013    krish

# %%
pd.read_csv('test.csv',names = ['bdcf','bcwb','ufag','igasdg'])
# Out:
#                        bdcf       bcwb     ufag   igasdg
# name                emailid    address  pincode  sirname
# bhargva   bhargav@gmail.com      amity   535126  killada
# krish        krish@iisc.com  bangalore   560012     sudh
# sudanshu     sudh@yahoo.com  bangalore   560013    krish

# %%
pd.read_csv('test.csv',names = ['bdcf','bcwb','ufag'])
# Out:
#                                  bdcf     bcwb     ufag
# name     emailid              address  pincode  sirname
# bhargva  bhargav@gmail.com      amity   535126  killada
# krish    krish@iisc.com     bangalore   560012     sudh
# sudanshu sudh@yahoo.com     bangalore   560013    krish

# %%
pd.read_csv('test.csv',names = ['bdcf','bcwb','ufag','uihvv','ighffh'])
# Out:
#        bdcf               bcwb       ufag    uihvv   ighffh
# 0      name            emailid    address  pincode  sirname
# 1   bhargva  bhargav@gmail.com      amity   535126  killada
# 2     krish     krish@iisc.com  bangalore   560012     sudh
# 3  sudanshu     sudh@yahoo.com  bangalore   560013    krish

# %%
pd.read_csv('test.csv',names = ['bdcf','bcwb','ufag','igfsb','uihvv','ighffh'])
# Out:
#        bdcf               bcwb       ufag    igfsb    uihvv  ighffh
# 0      name            emailid    address  pincode  sirname     NaN
# 1   bhargva  bhargav@gmail.com      amity   535126  killada     NaN
# 2     krish     krish@iisc.com  bangalore   560012     sudh     NaN
# 3  sudanshu     sudh@yahoo.com  bangalore   560013    krish     NaN

# %%
pd.read_csv('test.csv')
# Out:
#              name*emailid*address*pincode*sirname
# 0  bhargva*bhargav@gmail.com*amity*535126*killada
# 1      krish*krish@iisc.com*bangalore*560012*sudh
# 2  sudanshu*sudh@yahoo.com*bangalore*560013*krish

# %%
df = pd.read_csv('test.csv',sep = '*')

# %% [markdown]
#     we cannot use more than one separator at a time

# %%
df
# Out:
#        name            emailid    address  pincode  sirname
# 0   bhargva  bhargav@gmail.com      amity   535126  killada
# 1     krish     krish@iisc.com  bangalore   560012     sudh
# 2  sudanshu     sudh@yahoo.com  bangalore   560013    krish

# %%
pd.read_csv('test.csv',sep ='*', skiprows=[1])
# Out:
#        name         emailid    address  pincode sirname
# 0     krish  krish@iisc.com  bangalore   560012    sudh
# 1  sudanshu  sudh@yahoo.com  bangalore   560013   krish

# %%
df.dtypes
# Out:
# name       object
# emailid    object
# address    object
# pincode     int64
# sirname    object
# dtype: object

# %%
df.head(2) # if we dont give a number, defultly top 5 records it will shows
# Out:
#       name            emailid    address  pincode  sirname
# 0  bhargva  bhargav@gmail.com      amity   535126  killada
# 1    krish     krish@iisc.com  bangalore   560012     sudh

# %%
df.tail(2) # from end
# Out:
#        name         emailid    address  pincode sirname
# 1     krish  krish@iisc.com  bangalore   560012    sudh
# 2  sudanshu  sudh@yahoo.com  bangalore   560013   krish

# %%
df.columns
# Out:
# Index(['name', 'emailid', 'address', 'pincode', 'sirname'], dtype='object')

# %%
df['emailid']
# Out:
# 0    bhargav@gmail.com
# 1       krish@iisc.com
# 2       sudh@yahoo.com
# Name: emailid, dtype: object

# %%
a = df['address']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
#     two types in pandas
#     1. data frame : combination of multiple series
#     2. series : when we read a single column or row

# %%
df['name','emailid']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name', 'emailid')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
b = df[['name','emailid']] # pass a list  of column names

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#     Here the data read using of list of columns, but only one given in list. So dataframe

# %%
path = r'C:\Users\bharg\PycharmProjects\jupyter\sample-excel-master'

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx')
# Out:
#     Unnamed: 0                                   Unnamed: 1  \
# 0          NaN  This sheet allows you to manage executions:
# 1          NaN                           1. List executions
# 2          NaN                             2. Get execution
# 3          NaN                         3. Upsert executions
# 4          NaN                                          NaN
# ..         ...                                          ...
# 65         NaN                                          NaN
# 66         NaN                                          NaN
# 67         NaN                                          NaN
# 68         NaN                                          NaN
# 69         NaN                                          NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
#     This is the very first sheet in that excel file

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx', sheet_name='Allocations')
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.read_excel('LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df = pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name= i)

# %%
pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13572\2188339314.py in <module>
# ----> 1 pd.read_csv('https://github.com/datasciencedojo/datasets/blob/master/titanic.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
#     View the file in raw mode, then use the URL to load the data

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # day 2

# %% [markdown]
# https://www.basketball-reference.com/leagues/NBA_2015_totals.html

# %%
import pandas as pd

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
len(df) # gives no of tables avilable in the webpage
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#     from the webpage , it will sracp only table that too the data set avilable in table container, <tr>, <tc> tags only will be extracted not all the tabbles

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1.tail(10)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 665  485  Brandan Wright  PF  27  PHO  40   7   858  120  207  ...  .667   70
# 666  486   Dorell Wright  SF  29  POR  48   2   592   72  190  ...  .810   14
# 667  487     Tony Wroten  PG  21  PHI  30  15   895  175  434  ...  .667   22
# 668  488     James Young  SG  19  BOS  31   0   332   36  102  ...  .552    9
# 669  489      Nick Young  SG  29  LAL  42   0  1000  174  476  ...  .892   17
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 665  124  194   23   32  47   16   54   280
# ...

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1.to_csv('NBA_2015.csv') # this one stores the pandas indexing (intial serial number which is not actual data)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is CCAA-9AC8
#
#  Directory of C:\Users\bharg\PycharmProjects\jupyter
#
# 06-12-2022  10:07    <DIR>          .
# 06-12-2022  10:07    <DIR>          ..
# 24-11-2022  19:24    <DIR>          .ipynb_checkpoints
# 08-11-2022  15:27    <DIR>          __pycache__
# 05-11-2022  09:51            23,924 123.png
# 24-08-2020  18:09           132,917 14419.jpg
# 01-11-2022  18:26    <DIR>          19.3 MongoDB
# 09-11-2022  10:44               207 books.csv
# 09-11-2022  10:53             8,192 books.db
# 30-10-2022  15:45            51,867 car.data
# 30-10-2022  15:50             3,097 car.names
# 02-11-2022  09:38           628,633 carbon_nanotubes.csv
# 24-11-2022  19:20             2,507 Cassandra.ipynb
# 30-10-2022  09:32            11,903 glass.data
# 05-11-2022  15:08    <DIR>          GUI Programming
# 07-11-2022  22:47            10,299 GUI.ipynb
# 02-11-2022  11:17             8,192 ineuron.db
# ...

# %%
df1.to_csv('NBA_2015.csv',index = False)

# %%
d = """
{'name': 'bhargav',
'emailid': 'bhargav@gmail.com',
'tech': ['ml','dl','cv', 'rl','da'],
'platform': ['techneuron','kidsneuron','ineuron']
}
"""

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13572\2567112034.py in <module>
# ----> 1 pd.DataFrame(d)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
import json

# %%
result = json.loads(d)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13572\4022667153.py in <module>
# ----> 1 result = json.loads(d)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
# ...

# %%
d = """
{"name": "bhargav",
"emailid": "bhargav@gmail.com",
"tech": ["ml","dl","cv", "rl","da"],
"platform": ["techneuron","kidsneuron","ineuron"]
}
"""

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'bhargav',
#  'emailid': 'bhargav@gmail.com',
#  'tech': ['ml', 'dl', 'cv', 'rl', 'da'],
#  'platform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.read_json(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13572\3565998326.py in <module>
# ----> 1 pd.read_json(result)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
pd.DataFrame(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13572\3023930414.py in <module>
# ----> 1 pd.DataFrame(result)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %%
d = """
{"name": "bhargav",
"emailid": "bhargav@gmail.com",
"tech": ["ml","dl","cv"],
"platform": ["techneuron","kidsneuron","ineuron"]
}
"""

# %%
result = json.loads(d)

# %%
pd.DataFrame(result)
# Out:
#       name            emailid tech    platform
# 0  bhargav  bhargav@gmail.com   ml  techneuron
# 1  bhargav  bhargav@gmail.com   dl  kidsneuron
# 2  bhargav  bhargav@gmail.com   cv     ineuron

# %%
result['tech']
# Out:
# ['ml', 'dl', 'cv']

# %%
result['name']
# Out:
# 'bhargav'

# %%
pd.DataFrame(result["name"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13572\2734000829.py in <module>
# ----> 1 pd.DataFrame(result["name"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
pd.DataFrame(result["tech"])
# Out:
#     0
# 0  ml
# 1  dl
# 2  cv

# %% [markdown]
#     list to dataframe possiable

# %%
d = {"name": "bhargav","emailid": "bhargav@gmail.com","tech": ["ml","dl","cv"],"platform": ["techneuron","kidsneuron","ineuron"]}

# %%
pd.DataFrame(d)
# Out:
#       name            emailid tech    platform
# 0  bhargav  bhargav@gmail.com   ml  techneuron
# 1  bhargav  bhargav@gmail.com   dl  kidsneuron
# 2  bhargav  bhargav@gmail.com   cv     ineuron

# %%
del d["emailid"]
d.popitem()

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50082',
#   'id': 1478075405,
#   'node_id': 'PR_kwDOAA0YD85EbRpL',
#   'number': 50082,
#   'title': 'BUG: DatetimeArray.astype(Sparse)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
len(data1) #30 dicts are avilable in data1
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50082/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/50082',
#  'id': 1478075405,
#  'node_id': 'PR_kwDOAA0YD85EbRpL',
#  'number': 50082,
#  'title': 'BUG: DatetimeArray.astype(Sparse)',
#  'user': {'login': 'jbrockmendel',
#   'id': 8078968,
#   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbrockmendel',
#   'html_url': 'https://github.com/jbrockmendel',
#   'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
# ...

# %%
data1[0]['user']
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
# ...

# %%
data1[0]['user']['id']
# Out:
# 8078968

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 8078968
# 45562402
# 30958850
# 42917737
# 8519523
# 30958850
# 26364415
# 11656932
# 33491632
# 33491632
# 33491632
# 19598248
# 61934744
# 61934744
# 40615374
# 61934744
# 28446653
# 116989963
# 116989963
# 33491632
# 61934744
# 47963215
# 33491632
# 28446653
# 26364415
# 33491632
# 32019551
# 10820686
# 61934744
# 61934744

# %%
pd.DataFrame(data1)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(data1, columns=["url","repository_url","lable_url",'id'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(data1, columns=["url","repository_url","lable_url",'id',"user"])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df2 = pd.DataFrame(data1, columns=["url","repository_url","lable_url",'id', 'user'])

# %%
df2.to_csv('git_url.csv')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is CCAA-9AC8
#
#  Directory of C:\Users\bharg\PycharmProjects\jupyter
#
# 06-12-2022  11:59    <DIR>          .
# 06-12-2022  11:59    <DIR>          ..
# 24-11-2022  19:24    <DIR>          .ipynb_checkpoints
# 08-11-2022  15:27    <DIR>          __pycache__
# 05-11-2022  09:51            23,924 123.png
# 24-08-2020  18:09           132,917 14419.jpg
# 01-11-2022  18:26    <DIR>          19.3 MongoDB
# 09-11-2022  10:44               207 books.csv
# 09-11-2022  10:53             8,192 books.db
# 30-10-2022  15:45            51,867 car.data
# 30-10-2022  15:50             3,097 car.names
# 02-11-2022  09:38           628,633 carbon_nanotubes.csv
# 24-11-2022  19:20             2,507 Cassandra.ipynb
# 06-12-2022  11:59            32,533 git_url.csv
# 30-10-2022  09:32            11,903 glass.data
# 05-11-2022  15:08    <DIR>          GUI Programming
# 07-11-2022  22:47            10,299 GUI.ipynb
# ...

# %% [markdown]
#     Q. Flatten the above file by extarcting dicts and making columns the key values in those dictionaries
