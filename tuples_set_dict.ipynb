# %%
t = (1,2,"bhargav",1+3j,True, 548.454)

# %%
t[1]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-9b4ed128cf04> in <module>
# ----> 1 t[1]=4
#
# TypeError: 'tuple' object does not support item assignment

# %%
l = [1,2,"bhargav",1+3j,True, 548.454]

# %%
t1=(1,[2,'njifa'],"bhargav",1+3j,True, 548.454)

# %%
t1[1][1]=5

# %%
t1
# Out:
# (1, [2, 5], 'bhargav', (1+3j), True, 548.454)

# %%
tuple(l)
# Out:
# (1, 2, 'bhargav', (1+3j), True, 548.454)

# %%
type(l)
# Out:
# list

# %%
l=[1,2,3,4,4,5,2,1,3,4,6,7,2,50]

# %% [markdown]
# #remove duplicates

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 50}

# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
s2={2,3,4}

# %%
s1={1,2,3,4,4,5,2,1,3,4,6,7,2,50}

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 50}

# %%
type(s2)
# Out:
# set

# %%
type(s2)
# Out:
# set

# %%
s2[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-216-ab7c8e26b0d3> in <module>
# ----> 1 s2[0]
#
# TypeError: 'set' object is not subscriptable

# %%
list(s1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 50]

# %%
type(s1)
# Out:
# set

# %%
s1.add(0.2545)

# %%
s1
# Out:
# {0.2545, 1, 2, 3, 4, 5, 6, 7, 50}

# %%
s1.add(8)

# %%
s1
# Out:
# {0.2545, 1, 2, 3, 4, 5, 6, 7, 8, 50}

# %%
s1.add('vbhs')

# %%
s1
# Out:
# {0.2545, 1, 2, 3, 4, 5, 50, 6, 7, 8, 'vbhs'}

# %%
type(s1)
# Out:
# set

# %%
s1.add([2,'ffg',4554.25])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-226-67cf29f42382> in <module>
# ----> 1 s1.add([2,'ffg',4554.25])
#
# TypeError: unhashable type: 'list'

# %%
s1.add('jiadh')

# %%
s1
# Out:
# {0.2545, 1, 2, 3, 4, 5, 50, 6, 7, 8, 'jiadh', 'vbhs'}

# %%
{(2,3,4,2,3,4,5),5,3,3,4,5,5}
# Out:
# {(2, 3, 4, 2, 3, 4, 5), 3, 4, 5}

# %%
{(2,3,4,2,3,4,5),(5,3,3,4,5,5),5,2,2,3,4}
# Out:
# {(2, 3, 4, 2, 3, 4, 5), (5, 3, 3, 4, 5, 5), 2, 3, 4, 5}

# %%
{(2,3,4,2,3,4,5),(2,3,4,2,3,4,5),5,2,2,3,4}
# Out:
# {(2, 3, 4, 2, 3, 4, 5), 2, 3, 4, 5}

# %%
s1.add((2, 3, 4, 2, 3, 4, 5))

# %%
s1
# Out:
# {(2, 3, 4, 2, 3, 4, 5), 0.2545, 1, 2, 3, 4, 5, 50, 6, 7, 8, 'jiadh', 'vbhs'}

# %%
s1.remove(4)

# %%
s1
# Out:
# {(2, 3, 4, 2, 3, 4, 5), 0.2545, 1, 2, 3, 5, 50, 6, 7, 8, 'jiadh', 'vbhs'}

# %%
s1.discard(4)

# %%
s1
# Out:
# {(2, 3, 4, 2, 3, 4, 5), 0.2545, 1, 2, 3, 5, 50, 6, 7, 8, 'jiadh', 'vbhs'}

# %%
s1.discard(1)

# %%
s1
# Out:
# {(2, 3, 4, 2, 3, 4, 5), 0.2545, 2, 3, 5, 50, 6, 7, 8, 'jiadh', 'vbhs'}

# %%
s1.remove(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-240-1b8856482903> in <module>
# ----> 1 s1.remove(1)
#
# KeyError: 1

# %%
s1.discard(1)

# %%
{'bhargav','Bhargav'}
# Out:
# {'Bhargav', 'bhargav'}

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={2,3}

# %%
type(d1)
# Out:
# set

# %%
d={4:'bhargva'}

# %%
d
# Out:
# {4: 'bhargva'}

# %%
d1={'key1':'Killada','key2':'bhargav','key3': 26 , 1:664,2:'jhbhifwi',4 : [2,'kjfhsdfh',True]}

# %%
d1
# Out:
# {'key1': 'Killada',
#  'key2': 'bhargav',
#  'key3': 26,
#  1: 664,
#  2: 'jhbhifwi',
#  4: [2, 'kjfhsdfh', True]}

# %%
d1['key1']
# Out:
# 'Killada'

# %%
d1[2]
# Out:
# 'jhbhifwi'

# %%
d1[4]
# Out:
# [2, 'kjfhsdfh', True]

# %%
d={'key':{3,3,4,5}}

# %%
d['key']
# Out:
# {3, 4, 5}

# %%
d2={'key':{3,3,4,5},'key':45, 'key1':'hjbhuf'}

# %%
d2
# Out:
# {'key': 45, 'key1': 'hjbhuf'}

# %%
d1.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3', 1, 2, 4])

# %%
d1.values()
# Out:
# dict_values(['Killada', 'bhargav', 26, 664, 'jhbhifwi', [2, 'kjfhsdfh', True]])

# %%
d1.items()
# Out:
# dict_items([('key1', 'Killada'), ('key2', 'bhargav'), ('key3', 26), (1, 664), (2, 'jhbhifwi'), (4, [2, 'kjfhsdfh', True])])

# %%
type(d1.items())
# Out:
# dict_items

# %%
d1['key1']= 45

# %%
d1
# Out:
# {'key1': 45,
#  'key2': 'bhargav',
#  'key3': 26,
#  1: 664,
#  2: 'jhbhifwi',
#  4: [2, 'kjfhsdfh', True]}

# %%
d1['key4']={1:5,2:'jnhfsh'}

# %%
d1
# Out:
# {'key1': 45,
#  'key2': 'bhargav',
#  'key3': 26,
#  1: 664,
#  2: 'jhbhifwi',
#  4: [2, 'kjfhsdfh', True],
#  'key4': {1: 5, 2: 'jnhfsh'}}

# %%
d1['key4'][2]
# Out:
# 'jnhfsh'

# %%
del d1['key1']

# %%
d1
# Out:
# {'key2': 'bhargav',
#  'key3': 26,
#  1: 664,
#  2: 'jhbhifwi',
#  4: [2, 'kjfhsdfh', True],
#  'key4': {1: 5, 2: 'jnhfsh'}}

# %%
del d1

# %%
d1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-270-2d3a24957153> in <module>
# ----> 1 d1
#
# NameError: name 'd1' is not defined

# %%
d1={'key1':'Killada','key2':'bhargav','key3': 26 , 1:664,2:'jhbhifwi',4 : [2,'kjfhsdfh',True]}

# %%
d1
# Out:
# {'key1': 'Killada',
#  'key2': 'bhargav',
#  'key3': 26,
#  1: 664,
#  2: 'jhbhifwi',
#  4: [2, 'kjfhsdfh', True]}

# %%
d1.get('jfajh')
#no error will come

# %%
#if key is present value will be returnned
d1.get('key1')
# Out:
# 'Killada'

# %%
d1.update(d)

# %%
d1
# Out:
# {'key1': 'Killada',
#  'key2': 'bhargav',
#  'key3': 26,
#  1: 664,
#  2: 'jhbhifwi',
#  4: [2, 'kjfhsdfh', True],
#  'key': {3, 4, 5}}

# %%
d1+d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-277-0137565b964a> in <module>
# ----> 1 d1+d
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
l=[1,2,3,4]
l.append(l)

# %%
l
# Out:
# [1, 2, 3, 4, [...]]

# %%
t1=('bhargva',2,5+6j,True)

# %%
t1
# Out:
# ('bhargva', 2, (5+6j), True)

# %%
t1.index(True)
# Out:
# 3

# %%
t1=('bhargva',1,5+6j,True)

# %%
t1
# Out:
# ('bhargva', 1, (5+6j), True)

# %%
t1.index(True)
# Out:
# 1

# %%
key = ('name','email','ADD')
value = 'bhsargav'

# %%
d1.fromkeys(key, value)
# Out:
# {'name': 'bhsargav', 'email': 'bhsargav', 'ADD': 'bhsargav'}

# %%
d1
# Out:
# {'key1': 'Killada',
#  'key2': 'bhargav',
#  'key3': 26,
#  1: 664,
#  2: 'jhbhifwi',
#  4: [2, 'kjfhsdfh', True],
#  'key': {3, 4, 5}}
