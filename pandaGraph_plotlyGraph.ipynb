# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(1000), columns= ['data'])

# %%
df
# Out:
#          data
# 0   -0.847813
# 1   -0.224363
# 2   -0.518024
# 3    0.069205
# 4   -1.228539
# ..        ...
# 995  0.052434
# 996 -0.569329
# 997 -0.792292
# 998 -0.688456
# 999 -0.815935
#
# [1000 rows x 1 columns]

# %%
df.plot() # this plot function in pandas library, using kind attribute we need to plot required graph
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000), columns= ['data'], index = pd.date_range('2023/02/06', periods = 1000))

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ir = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
ir.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
ir.head(10).plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
ir.head(10).plot(kind = 'barh', figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
ir.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ir.plot(kind='hist', orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
ir
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ir.hist(figsize=(20,10), color = 'g')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
ir.hist(figsize=(20,10), color = 'g', alpha = 0.5) #alpha is intensity of the color (constrast)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
ir.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
ir.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [raw]
# IQR = inter quartile range (75%-25%)
# lower bound for box(Q1) = 25%
# higher bound for box (Q3)= 75%
# middel line in the box (Q2) = 50%
#
# min = lower line = Q1 - 1.5(IQR)
# max = upper line = Q3 + 1.5(IQR)
#
# If the data set any values having the min or max calcultaed using IQR will be shown as dots.
# if the dataset doesnot have any such values then the dataset max and min will be marked as upper and lower line.

# %%
ir.plot(kind = 'box', color = {'boxes' : 'g','whiskers': 'r'}) #vert = Flase for Horizontal box graph
# Out:
# <AxesSubplot:>

# %%
ir.plot(kind = 'area', figsize = (20,10), alpha = 0.5)
# Out:
# <AxesSubplot:>

# %%
ir.plot(kind = 'area', figsize = (20,10), stacked = False)
# Out:
# <AxesSubplot:>

# %%
ir
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ir.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
ir.plot.scatter(x = 'sepal_length', y = 'petal_length', c ='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
ir.plot.scatter(x = 'sepal_length', y = 'petal_length', c ='sepal_width', s = 200) # s represents size
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
ir.plot.hexbin(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
ir.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
ir.loc[[0]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
df1 = ir.drop(columns='species').iloc[0]

# %%
df1.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
 # !pip install plotly

# %%
ir
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6608\189640202.py in <module>
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
# !pip install cufflinks
# Out:
# ...
#      ---------------------------------------- 81.7/81.7 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68718 sha256=c1254159ab06d580e7e2686a2a41536399f9d382c0771270c97b3a8af43b93bf
#   Stored in directory: c:\users\bharg\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
import cufflinks as cf

# %%
ir.iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430                 try:
# -> 1431                         import chart_studio.plotly as py
#    1432                 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6608\2774088725.py in <module>
# ----> 1 ir.iplot()
#
# ...

# %%
# !pip install chart_studio
# Out:
# ...
#      ---------------------------------------- 64.4/64.4 kB 3.6 MB/s eta 0:00:00
# ...

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ir.iplot()
# Out:
# <div>                            <div id="a62b3571-a06a-4148-9982-2cf7e60005f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ir.iplot(x = 'sepal_length', y = 'petal_length', mode = 'markers' )
# Out:
# <div>                            <div id="ed1a8cce-3bea-41bc-b92c-01a25dcd3a75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ir.iplot(kind = 'scatter', mode = 'markers', size = 5)
# Out:
# <div>                            <div id="ad270dda-eefe-4b5a-8525-40cacb665fac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ir.iplot(kind = 'bubble', x = 'sepal_length', y = 'petal_length', size = 'sepal_width') #size is mandatory
# Out:
# <div>                            <div id="a641199b-827e-4824-b489-7c7fea175e1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
 ir.scatter_matrix()
# Out:
# <div>                            <div id="ab62a695-fba1-49cb-bd08-93223260ca72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ir
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ir.head().iplot(kind = 'scatter3d', x = 'sepal_length', y  ='sepal_width', z = 'petal_length')
# Out:
# <div>                            <div id="98623fec-b7b6-487f-bbd7-995aba9d6f3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ir.head().iplot(kind = 'bubble3d', x = 'sepal_length', y  ='sepal_width', z = 'petal_length', size = 'sepal_width')
# Out:
# <div>                            <div id="ed75d844-1b1f-44bc-828a-b68e451e8a2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
