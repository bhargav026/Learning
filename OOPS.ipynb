# %%
l= [2,3,4,5]
for i in l:
  print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
class car:
  pass

# %%
class car:
  def __init__(self,brand_name, fueltype, body_type):
    self.brand_name = brand_name
    self.fueltype = fueltype
    self.body_type = body_type

  def desc_car():
    print(self.brand_name, self.fueltype, self.body_type)

# %%
innova = car()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4739df149d2c> in <module>
# ----> 1 innova = car()
#
# TypeError: __init__() missing 3 required positional arguments: 'brand_name', 'fueltype', and 'body_type'

# %%
innova = car('toyota','petrol','suv')

# %%
innova.desc_car()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-cfdb7103a8d5> in <module>
# ----> 1 innova.desc_car()
#
# TypeError: desc_car() takes 0 positional arguments but 1 was given

# %%
class car:
  def __init__(self,brand_name, fueltype, body_type):
    self.brand_name = brand_name
    self.fueltype = fueltype
    self.body_type = body_type

  def desc_car(self):
    print(self.brand_name, self.fueltype, self.body_type)

# %%
innova = car('toyota','petrol','suv')

# %%
 innova.desc_car()
# Out:
# toyota petrol suv

# %%
nexon = car('tata','petrol','min suv')

# %%
nexon.desc_car()
# Out:
# tata petrol min suv

# %%
a = 10

# %%
s = 'sudh'

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(innova)
# Out:
# __main__.car

# %%
innova.body_type
# Out:
# 'suv'

# %%
innova1=car(56,8,54)

# %%
innova.desc_car()
# Out:
# toyota petrol suv

# %%
class van:
  def test(Bhargav):
    print('this is a class with any inputs')

# %%
a=van()

# %%
a.test()
# Out:
# this is a class with any inputs

# %%
class van:
  def test(Bhargav,a,b):
    print('this is a class with any inputs',a,b)

# %%
a=van()

# %%
a.test('jb','hiuh')
# Out:
# this is a class with any inputs jb hiuh

# %%
print(type(a))
# Out:
# <class '__main__.van'>

# %%
class list_parser:
  def parser(self,a):
    if type(a)==list:
      for i in a:
        print(i)
  def reverser(self,z):
    if type(z)==list:
      return z[::-1]

# %%
c=list_parser()

# %%
c.parser([2,3,4,5,6])
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
c.reverser([2,3,4,5,6])
# Out:
# [6, 5, 4, 3, 2]

# %%
class list_parser:
  def __init__(self,l):
    self.a = l
  def parser(self):
    if type(self.a)==list:
      for i in self.a:
        print(i)
  def reverser(self):
    if type(self.a)==list:
      return self.a[::-1]

# %%
a = list_parser([2,3,4,5])

# %%
a.reverser()
# Out:
# [5, 4, 3, 2]

# %%
create a class for dictionary parsing
1.write a function to give all the keys
2.write a function to give all the values
3.write a fucntion to throw an exception in  ase of input is not a dictioanry 
4.write a function to take user input and then parse a key and value out of dictionary
5. write a function to insert new key value pair it=nto dictionary

# %%
class diction:
  def __init__(self,a):
    self.a = a
  def is_dic(self):
    if type(self.a) == dict:
      return True
    else:
      raise Exception('input is not a dictionary')
  def dic_keys(self):
    if self.is_dic():
        return list(self.a.keys())
  def dic_values(self):
    if self.is_dic():
      return list(self.a.values())
  def dic_item(self):
    if self.is_dic():
      n = input('enter dictionary key:')
      try:
        print(n,':',self.a[n])
      except KeyError as e:
        try:
          print(n,':',self.a[int(n)])
        except Exception as e:
          print('Enter a valid key')
    def userinput(self):
      self.a = eval(input())
      print(self.a, type(self.a))
      print(self.dic_keys())
      print(self.dic_keys())
  def append_item(self,key,value):
    if self.is_dic():
      self.a[key] = value

# %%
bhargav = diction({'bdu':584,'bwhn':6548441,54:'jbncb'})

# %%
bhargav.is_dic()
# Out:
# True

# %%
bhargav.dic_keys()
# Out:
# ['bdu', 'bwhn', 54]

# %%
bhargav.dic_values()
# Out:
# [584, 6548441, 'jbncb']

# %%
bhargav.dic_item()
# Out:
# enter dictionary key:85
# Enter a valid key

# %%
bhargav.dic_item()
# Out:
# enter dictionary key:54
# 54 : jbncb

# %%
bhargav.append_item(57,8955)

# %%
bhargav.dic_keys()
# Out:
# ['bdu', 'bwhn', 54, 57]

# %%
bhargav.dic_item()
# Out:
# enter dictionary key:57
# 57 : 8955

# %%
cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
open('mydict.py','w')
# Out:
# <_io.TextIOWrapper name='mydict.py' mode='w' encoding='UTF-8'>

# %%
ls
# Out:
#  AE1.ipynb                    'Exception handling.ipynb'
#  AE_fader.ipynb                fader_AE_No_disc_latent2.jpeg
#  AE.ipynb                      Fader_network2.ipynb
#  AE_MSE_loss5_1.jpeg           Fader_Network3.ipynb
#  AE_MSE_loss5.jpeg             FaderNetwork.ipynb
#  AE_MSE_loss5_MP_1000.jpeg     functions.ipynb
#  AE_MSE_loss5_MP.jpeg          functions.py
#  AE_MSE_loss.jpeg             'If, Else, for, while loop.ipynb'
#  AE_MSE_loss_new_model1.jpeg   ineuron.ipynb
#  AE_MSE_loss_new_model2.jpeg   ISTAnet1.ipynb
#  AE_MSE_loss_new_model3.jpeg   ISTAnet2.ipynb
#  AE_Samples.ipynb              Iterator_Generator_filesystem.ipynb
#  error1.jpeg                   logging_in_python.ipynb
#  error2.jpeg                   logging.ipynb
#  error3.jpeg                   main.py
#  error4.jpeg                  'media outage.ipynb'
#  error5_1.jpeg                 module2.py
#  error5_2.jpeg                 Module_Packages.ipynb
#  error5.jpeg                   module.py
# ...

# %% [markdown]
# copy diction class and  its functions into mydict.py module.
#
# ---
#
# then import the file and then you can you the class and its properties , check Module_packages.ipynb file

# %% [markdown]
# # OOPS PART-2
# Inheritence, polymorphisam, encapsulisim

# %%
class xyz:
  def __init__(self , a,b,c):
    self.a = a
    self.b = b
    self.c = c

  def test(self):
    print('test')
  
  def test1(self):
    print('test1')

  def test2(self):
    print('test2')

# %%
class xyz1(xyz): #we are trying to inherit the properties of xyz in xyz1
  def test3(self):
    print('test3')

# %%
pqr = xyz(1,2,3)

# %%
pqr.test()
# Out:
# test

# %%
pqr.b
# Out:
# 2

# %%
qwe = xyz1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-21f7bd1c4dbf> in <module>
# ----> 1 qwe = xyz1()
#
# TypeError: __init__() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
qwe = xyz1(2,3,4)

# %%
qwe.test1()
# Out:
# test1

# %%
qwe.test3()
# Out:
# test3

# %%
class xyz2(xyz1):
  pass

# %%
wer = xyz2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-5e8bcce4d1ce> in <module>
# ----> 1 wer = xyz2()
#
# TypeError: __init__() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
wer = xyz2(5,6,8)

# %%
wer.test3()
# Out:
# test3

# %%
class xyz2(xyz1):
  def test(self):
    print('this is test from xyz2')

# %%
wer = xyz2(4,5,6)

# %%
wer.test()
# Out:
# this is test from xyz2

# %%
class xyz():
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c = c
  def test(self):
    print('this is test from xyz')

# %%
wer.test()
# Out:
# this is test from xyz2

# %%
class xyz():
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c = c
  def test(self):
    print('this is test from xyz')

class xyz1():
  def __init__(self,p,q,r):
    self.p=p
    self.q=q
    self.r = r
  def test1(self):
    print('this is test from xyz1')

# %%
class child(xyz,xyz1):
  pass

# %%
x = child(4,5,6)

# %%
x.a
# Out:
# 4

# %%
class child1(xyz1,xyz):
  pass

# %%
e=child1(5,6,7)

# %%
e.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-202-31085a61c859> in <module>
# ----> 1 e.a
#
# AttributeError: 'child1' object has no attribute 'a'

# %%
e.p
# Out:
# 5

# %%
x = child(1,2,3,4,5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-dc5af43feb89> in <module>
# ----> 1 x = child(1,2,3,4,5,6)
#
# TypeError: __init__() takes 4 positional arguments but 7 were given

# %%
class child(xyz, xyz1):
  def __init__(self):
    xyz.__init__(self)
    xyz1.__init__(self)

# %%
v = child(1,2,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-208-d10798cf6169> in <module>
# ----> 1 v = child(1,2,2)
#
# TypeError: __init__() takes 1 positional argument but 4 were given

# %%
class child(xyz, xyz1):
  def __init__(self,*args):
    xyz.__init__(self,*args)
    xyz1.__init__(self,*args)

# %%
v = child(1,2,2)

# %%
v.b
# Out:
# 2

# %%
v.p
# Out:
# 1

# %%
class child(xyz, xyz1):
  def __init__(self,*args,*args1):
    xyz.__init__(self,*args)
    xyz1.__init__(self,*args1)
# Out:
#   File "<ipython-input-215-c2d26151af36>", line 2
#     def __init__(self,*args,*args1):
#                             ^
# SyntaxError: invalid syntax

# %%
class child(xyz, xyz1):
  def __init__(self,*args,**kwargs):
    xyz.__init__(self,*args)
    xyz1.__init__(self,**kwargs)

# %%
y= child(4,5,6, p = 5, q = 8, r = 2)

# %%
y.a
# Out:
# 4

# %%
y.p
# Out:
# 5

# %%
y.q
# Out:
# 8

# %%
y.r
# Out:
# 2

# %%
q1. ceate a file class fro reading data from respective file with a method name read and write
q2.try to inherit read and write method from parent class to child class to perform read and write operation

# %%
class file():
  def __init__(self,filename):
    self.file = filename
  def read(self):
    f = open(self.file,'r')
    line = f.readline()
    while (line!=''):
      print(line)
      line = file2.readline()
    f.close()
  
  def write(self,lines):
    f = open(self.file,'w')
    f.writelines(lines)
    f.close()

class fileoperation(file):
  pass

# %% [markdown]
# Public , Private and protected

# %% [markdown]
# using notations we are going to define public, private , protected
#
# ---
#   _is for protected
# ---
# __for private

# %%
class xyz():
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c = c
  def test(self):
    print('this is test from xyz')
  
class child(xyz):
  pass

q=xyz(4,5,6)

# %%
q.a
# Out:
# 4

# %%
w=child(7,8,9)

# %%
w.a
# Out:
# 7

# %%
class xyz():
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c = c
  def test(self):
    print('this is test from xyz')
  
class child(xyz):
  self.a=4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-251-f4061e9de214> in <module>
#       7     print('this is test from xyz')
#       8
# ----> 9 class child(xyz):
#      10   self.a=4
#      11
#
# <ipython-input-251-f4061e9de214> in child()
#       8
#       9 class child(xyz):
# ---> 10   self.a=4
#      11
#      12 q=xyz(4,5,6)
#
# NameError: name 'self' is not defined

# %%
class xyz():
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c = c
  def test(self):
    print('this is test from xyz')
  
class child(xyz):
  def __init__(self):
    self.a=7

# %%
u = xyz(4,5,6)

# %%
v=child(8,8,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-267-cce468d85b8f> in <module>
# ----> 1 v=child(8,8,8)
#
# TypeError: __init__() takes 1 positional argument but 4 were given

# %%
u.a
# Out:
# 4

# %%
v=child()

# %%
v.a
# Out:
# 7

# %%
v.b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-271-b54f57164ac5> in <module>
# ----> 1 v.b
#
# AttributeError: 'child' object has no attribute 'b'

# %%
class xyz():
  def __init__(self):
    self.a=4
    #self.b=b
    #self.c = c
  def test(self):
    print('this is test from xyz')

class child(xyz):
  def __init__(self):
    xyz.__init__(self)
    self.a=7

u =xyz()
i = child()

# %%
u.a
# Out:
# 4

# %%
i.a
# Out:
# 7

# %%
class xyz():
  def __init__(self):
    self._a=4
    #self.b=b
    #self.c = c
  def test(self):
    print('this is test from xyz')

class child(xyz):
  def __init__(self):
    self._a=7

u =xyz()
i = child()

# %%
u._a
# Out:
# 4

# %%
i._a
# Out:
# 7

# %%
class xyz():
  def __init__(self):
    self.__a=4
    #self.b=b
    #self.c = c
  def test(self):
    print('this is test from xyz')

class child(xyz):
  def __init__(self):
    self.__a=7

u =xyz()
i = child()

# %%
u.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-295-45f5c7f66ea7> in <module>
# ----> 1 u.__a
#
# AttributeError: 'xyz' object has no attribute '__a'

# %%
i.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-296-45dbf2e853a9> in <module>
# ----> 1 i.__a
#
# AttributeError: 'child' object has no attribute '__a'

# %%
class test:
  def __init__(self,a,b,c):
    self.a = a
    self.b= b
    self.c = c

v= test(4,5,6)

# %%
print(v.a)
print(v.b)
print(v.c)
# Out:
# 4
# 5
# 6

# %%
class test:
  def __init__(self,a,b,c):
    self._a = a
    self.__b= b
    self.c = c

v= test(4,5,6)

# %%
print(v._a)
print(v.b)
print(v.c)
# Out:
# 4
# 5
# 6

# %%
print(v._a)
print(v.c)
print(v.__b)
# Out:
# 4
# 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-303-2f1f1e21264d> in <module>
#       1 print(v._a)
#       2 print(v.c)
# ----> 3 print(v.__b)
#
# AttributeError: 'test' object has no attribute '__b'

# %%
v._test__b
# Out:
# 5

# %%
class test:
  def __init__(self,a,b,c):
    self._a = a
    self.__b= b
    self.c = c

class test1(test):
  #def __init__(self):
   # test.__init__(self)
  pass

v= test(4,5,6)

# %%
print(v._a)
print(v.c)
print(v._test__b)
# Out:
# 4
# 6
# 5

# %%
u= test1(3,4,7)

# %%
u.c
# Out:
# 7

# %%
u.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-309-afa9342845d0> in <module>
# ----> 1 u.a
#
# AttributeError: 'test1' object has no attribute 'a'

# %%
u._a
# Out:
# 3

# %%
u._test1__b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-312-28b27c9c3546> in <module>
# ----> 1 u._test1__b
#
# AttributeError: 'test1' object has no attribute '_test1__b'

# %%
u._test__b
# Out:
# 4

# %%
v._test__b
# Out:
# 5

# %%
class bonuscalculator:
  def __init__(self, empid, emprating):
    self.empid =empid
    self.emprating = emprating
    self.__bonusforratingA = '70%'
    self.__bonusforratingB = '50%'

  def bonuscalculator(self):
    if self.emprating =='A':
      bonus = self.__bonusforratingA
    elif self.emprating =='B':
      bonus = self.__bonusforratingB
    else:
      bonus = '40%'
    return bonus

# %%
emp1 = bonuscalculator(101,'A')
emp2 = bonuscalculator(102,'B')
emp3 = bonuscalculator(103,'c')

# %%
emp1.bonuscalculator()
# Out:
# '70%'

# %%
emp2.bonuscalculator()
# Out:
# '50%'

# %%
emp3.bonuscalculator()
# Out:
# '40%'

# %%
emp1.empid = 105

# %%
emp1.empid
# Out:
# 105

# %%
emp1.emprating = 'C'

# %%
emp1.bonuscalculator()
# Out:
# '40%'

# %%
emp1.__bonusforratingB='80%'

# %%
emp1.bonuscalculator()
# Out:
# '40%'

# %%
emp1.__bonusforratingB
# Out:
# '80%'

# %%
emp1.emprating = 'B'

# %%
emp1.bonuscalculator()
# Out:
# '50%'

# %%
emp1._bonuscalculator__bonusforratingB='80%'

# %%
emp1.bonuscalculator()
# Out:
# '80%'

# %%
emp2.emprating = 'B'

# %%
emp2.bonuscalculator()
# Out:
# '50%'

# %% [markdown]
# # polymorphism

# %%
def test(a,b):
  return a+b

# %%
test(3,4) #addiion is happening
# Out:
# 7

# %%
test('jg','ghfigh') #concationation is happening
# Out:
# 'jgghfigh'

# %%
class insta:
  def share_stories(self):
    print('this is my insta story')

class facebook:
  def share_stories(self):
    print('this is facebook story')

# %%
def sharestories(app):
  app.share_stories()

# %%
i = insta()
f= facebook()

# %%
sharestories(i)
# Out:
# this is my insta story

# %%
sharestories(f)
# Out:
# this is facebook story

# %%
class social_media:
  def share_stories(self):
    print('share a stories')
  
  def upload_pic(self):
    print('this will help ou to add a picture')

class facebook(social_media):
  def share_stories(self):
    print('this is a fun for sharing a story for faceboo')

class insta(social_media):
  def share_stories(self):
    print('this is a insta story')

# %%
f=facebook()
i=insta()

# %%
f.share_stories()
# Out:
# this is a fun for sharing a story for faceboo

# %%
i.share_stories()
# Out:
# this is a insta story

# %%
f.upload_pic()
# Out:
# this will help ou to add a picture

# %%
i.upload_pic()
# Out:
# this will help ou to add a picture

# %%
class test(Exception):
  def __init__(self,msg):
    self.msg = msg

# %%
try:
  raise(test('this is my own exception class '))
except test as t:
  print(t)
# Out:
# this is my own exception class

# %%
try:
  5/0
except test as t:
  print(t)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-26-4c379d841552> in <module>
#       1 try:
# ----> 2   5/0
#       3 except test as t:
#       4   print(t)
#
# ZeroDivisionError: division by zero

# %%
try:
  raise(test('this is my own exception class '))
  5/0
except test as t:
  print(t)
# Out:
# this is my own exception class

# %%
try:
  5/0
  raise(test('this is my own exception class '))
except test as t:
  print(t)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-28-fe9cca5c183e> in <module>
#       1 try:
# ----> 2   5/0
#       3   raise(test('this is my own exception class '))
#       4 except test as t:
#       5   print(t)
#
# ZeroDivisionError: division by zero

# %%
"""q1. create your own class for to achive multilevel, multiple inheritence
q2. create your class to represent polymorphism
q3. create your own class for custom exception
q4. create your own class to achieve encapusalation
q5. create your own class to achieve method overloading and overriding """
# Out:
# 'q1. create your own class for to achive multilevel, multiple inheritence\nq2. create your class to represent polymorphism\nq3. create your own class for custom exception\nq4. create your own class to achieve encapusalation\nq5. create your own class to achieve method overloading and overriding '

# %%
#multiple inheritence
class batch_number():
  batchnumber='' #stativc variable or class variables
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c=c # instance variables or object variables
  def batch(self):
    print(self.batchnumber)
  
class course_name():
  course =''
  def course(self):
    print(self.course)

class student(batch_number,course_name):
  def details(self):
    print('batch:', self.batchnumber)
    print('course:',self.course)

s=student(4,5,65)
s.batchnumber = 123
s.course = 'happy'
s.details()
# Out:
# batch: 123
# course: happy

# %%
s.batchnumber
# Out:
# 123

# %%
s.a
# Out:
# 4

# %%
s.b
# Out:
# 5

# %%
s.c
# Out:
# 65

# %%
batch_number.batchnumber
# Out:
# ''

# %%
s.batchnumber = 784

# %%
s.batchnumber
# Out:
# 784

# %%
s2 = student(2,3,4)

# %%
s2.batchnumber
# Out:
# ''

# %%
batch_number.batchnumber = 444

# %%
s2.batchnumber
# Out:
# 444

# %%
s.batchnumber
# Out:
# 784

# %%
s2.batchnumber = 44545

# %%
s2.batchnumber
# Out:
# 44545

# %%
batch_number.batchnumber
# Out:
# 444

# %%
@staticmethod #decorator function will be used to make the function the as class function
# Out:
#   File "<ipython-input-52-d692c4447bdd>", line 1
#     @staticmethod #decorator function will be used to make the function the as class function
#                                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
class batch_number():
  batchnumber='**' #stativc variable or class variables
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c=c # instance variables or object variables
  
  @staticmethod       #no need to mention self in function def, the function in which below the staticmethod we have written work as class function
  def batch():
    print('hi')
    print(batch_number.batchnumber)  #

  def batch1(self):
    print('from batch1')


class course_name():
  course =''
  def course(self):
    print(self.course)

class student(batch_number,course_name):
  def details(self):
    print('batch:', self.batchnumber)
    print('course:',self.course)

s=student(4,5,65)
s.batchnumber = 123
s.course = 'happy'
s.details()
# Out:
# batch: 123
# course: happy

# %%
s.batch()
# Out:
# hi
# **

# %%
batch_number.batch()
# Out:
# hi
# **

# %%
s.batch1()
# Out:
# from batch1

# %%
batch_number.batch1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-6ee6674489ac> in <module>
# ----> 1 batch_number.batch1()
#
# TypeError: batch1() missing 1 required positional argument: 'self'

# %% [markdown]
# #abstraction

# %%
class abc:
  pass

# %%
class data_project():
  def read_file(self):
    pass

  def validate_file_name(self):
    pass

  def validate_data_type(self):
    pass
  
  def validate_db_conn(self):
    pass

  def create_conn(self):
    pass

  def insert_data(self):
    pass

  def perform_stats(self):
    pass

# %%
class abc:
  pass

# %%
from abc import abstractmethod #@abstractmethod we can use now

# %%
class test:
  def fun(self):
    print('this is my simple class')

# %%
t=test()

# %%
print(t)

# %%
class test:
  def fun(self):
    print('this is my simple class')
  
  def __str__(self):
    return 'this is a fun called at a time of object print'
     #return has to be in string format , while returning any intergers use str())

# %%
t=test()

# %%
print(t)
# Out:
# this is a fun called at a time of object print
