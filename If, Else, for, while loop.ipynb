# %%
 a=10

# %%
a<15
# Out:
# True

# %%
if a < 15:
  print('Bhargav')
# Out:
# Bhargav

# %%
if a < 15:
# Out:
#   File "<ipython-input-4-1b8069a28b2f>", line 1
#     if a < 15:
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
if a<15:
  pass

# %%
if a<15:
  
  print(a)
# Out:
# 10

# %%
224<15
# Out:
# False

# %%
if 24<15:
  print('bhargav')

# %%
if 3>10:
  print('right')
else:
  print('wrong')
# Out:
# wrong

# %%
income = 200
if income<50:
  print('i will be able to buy phone')
elif income <70:
  print('i will be able to buy car')
else:
  print('i cant purchase any thing')
# Out:
# i cant purchase any thing

# %%
income=input()
# Out:
# 54

# %%
income
# Out:
# '54'

# %%
type(income)
# Out:
# str

# %%
income=int(input())
# Out:
# 51

# %%
type(income)
# Out:
# int

# %%
income = float(input())
if income<50 and income>30:
  print('i will be able to buy phone')
elif income <70 and income>50:
  print('i will be able to buy car')
else:
  print('i cant purchase any thing')
# Out:
# 58
# i will be able to buy car

# %%
1.5456<1
# Out:
# False

# %%
l=[1,2,3,4,5]
for i in l:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a='bhargav'
for i in a:
  print(i)
# Out:
# b
# h
# a
# r
# g
# a
# v

# %%
t=(1,2,3,4,5,6)
for i in t:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
l=[1,4,5.6,6j,'bhargva']

# %%
for i in l:
  print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>

# %%
l=[1,2,4.6]
l1=[]
for i in l:
  print(i+2)
  l1.append(i+2)
# Out:
# 3
# 4
# 6.6

# %%
l1
# Out:
# [3, 4, 6.6]

# %%
l=[2,45,78,12,'sudh',6+4j,[56,67,78]]
for i in l:
  if int == type(i):
    print(i)
  elif type(i)==list:
    for j in i:
      if type(j)==int:
        print(j)
# Out:
# 2
# 45
# 78
# 12
# 56
# 67
# 78

# %%
l=[2,45,78,12,"sudh",6+7j,[56,67,78,'dfhgiuf']]

# %%
#index of all elements
for i in l:
  if type(i) == str or type(i)==list:
    for j in i:
      print(l.index(i),i.index(j))
  else:
    print(l.index(i))
# Out:
# 0
# 1
# 2
# 3
# 4 0
# 4 1
# 4 2
# 4 3
# 5
# 6 0
# 6 1
# 6 2
# 6 3

# %%
for i in range(len(l)):
  print('index',i,'for an element',l[i])
# Out:
# index 0 for an element 2
# index 1 for an element 45
# index 2 for an element 78
# index 3 for an element 12
# index 4 for an element sudh
# index 5 for an element (6+7j)
# index 6 for an element [56, 67, 78, 'dfhgiuf']

# %%
for i in enumerate(l):
  print(i)
# Out:
# (0, 2)
# (1, 45)
# (2, 78)
# (3, 12)
# (4, 'sudh')
# (5, (6+7j))
# (6, [56, 67, 78, 'dfhgiuf'])

# %%
for i,j in enumerate(l):
  print(i,j)
# Out:
# 0 2
# 1 45
# 2 78
# 3 12
# 4 sudh
# 5 (6+7j)
# 6 [56, 67, 78, 'dfhgiuf']

# %%
#list of char if the list is string
l1=[]
for i in l:
  if type(i) == str:
    for j in i:
      l1.append(j)
  elif type(i)==list:
    for j in i:
      if type(j) == str:
        for k in j:
          l1.append(k)
print(l1)
# Out:
# ['s', 'u', 'd', 'h', 'd', 'f', 'h', 'g', 'i', 'u', 'f']

# %%
#return a list sqaures if the element is int
l2=[]
for i in l:
  if type(i)==int:
    l2.append(i**2)
l2
# Out:
# [4, 2025, 6084, 144]

# %%
l=['name','email id','phone no','address']
for i in l:
  print(i)
# Out:
# name
# email id
# phone no
# address

# %% [markdown]
# for else statement

# %%
for i in l:
  print(i)
else:
  print('if for loop id going to complete itself then it will come to else ')
# Out:
# name
# email id
# phone no
# address
# if for loop id going to complete itself then it will come to else

# %%
for i in l:
  print(i)
  break
else:
  print('if for loop id going to complete itself then it will come to else ')
# Out:
# name

# %%
a=1
while a<6:
  print(a)
  a=a+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a=1
while a<6:
  if a==4:
    break
  print(a)
  a=a+1
# Out:
# 1
# 2
# 3

# %%
a=1
while a<6:
  print(a)
  if a==4:
    continue
  a=a+1
# Out:
# Streaming output truncated to the last 5000 lines.
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# ...

# %%
a=1
while a<6:
  print(a)
  a=a+1
  if a==4:
    continue
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
 a=1
while a<6:
  a=a+1

# %%
for i in l:
  pass

# %%
a=range(6)

# %%
print(a)
print(range(6))
# Out:
# range(0, 6)
# range(0, 6)

# %%
list(range(6))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
list(range(5,16,2))
# Out:
# [5, 7, 9, 11, 13, 15]

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list(range(3,10,-1))
# Out:
# []

# %%
list(range(10,4,-1))
# Out:
# [10, 9, 8, 7, 6, 5]

# %%
n=5
for i in range(0,n):
  for j in range(0,i+1):
    print('*', end='')
  print('\r')
# Out:
# *
# **
# ***
# ****
# *****

# %%
s='ojgofh jhgofhgo oijosifjgi sfg '
len(s)
# Out:
# 31

# %%
count=0
for i in s:
  #count=count+1
  count+=1
print(count)
# Out:
# 31

# %%
s[::-1]
# Out:
# ' gfs igjfisojio oghfoghj hfogjo'

# %%
for i in range(len(s)-1,-1,-1):
  print(s[i], end='')
# Out:
#  gfs igjfisojio oghfoghj hfogjo

# %%
i=len(s)-1
while i>=0:
  print(s[i], end='')
  i-=1
# Out:
#  gfs igjfisojio oghfoghj hfogjo

# %%
s1='AaEeIiOoUu'

# %%
for i in s:
  if i in s1:
    print('vowel',i)
  else:
    print("not vowel",i)
# Out:
# vowel o
# not vowel j
# not vowel g
# vowel o
# not vowel f
# not vowel h
# not vowel
# not vowel j
# not vowel h
# not vowel g
# vowel o
# not vowel f
# not vowel h
# not vowel g
# vowel o
# not vowel
# vowel o
# vowel i
# not vowel j
# vowel o
# not vowel s
# vowel i
# not vowel f
# not vowel j
# not vowel g
# vowel i
# not vowel
# not vowel s
# not vowel f
# not vowel g
# not vowel

# %%
's' in 'siuhd'
# Out:
# True

# %%
s2=input()
if s2==s2[::-1]:
  print('it is palindrome')
else: print("not")
# Out:
# jizdhfjiah
# not

# %%
s3='malayalam'
for i in range(int(len(s3)/2+0.5)):
  if s3[i]==s3[len(s3)-1-i]:
    pass
  else: 
    print('not')
    break
else: print('yes')
# Out:
# yes

# %%
d={'india':'IN','china':'CH','canada':'CA','newzland':'NZ'}

# %%
type(d.values())
# Out:
# dict_values

# %%
if 'india' in d:
  print(d['india'])
# Out:
# IN

# %%
l=[]
l2=[]
for i in d.keys(): #i in d:
  if len(i)>5:
    l.append(i)
  else:
    l2.append(i)
print(l)
print(l2)
# Out:
# ['canada', 'newzland']
# ['india', 'china']

# %%
dict1={'ineuron':{
    'a':15,
    'b':41,
    'c':54
      },
      'course':{
          'd':54,
          'e':65,
          'f':97
      }
       
       }

# %%
for i in dict1.values():
  l3=[]
  for j in i.values():
    l3.append(j)
  print(max(l3))
# Out:
# 54
# 97

# %%
for i in dict1.keys():
  print(max(dict1[i].values()))
# Out:
# 54
# 97

# %%
type(dict1['course'])
# Out:
# dict

# %%
for i in dict1:
  print(i)
  print(dict1[i].values())
# Out:
# ineuron
# dict_values([15, 41, 54])
# course
# dict_values([54, 65, 97])

# %%
dict1={ 'jhf':'jhfwi','ineuron':{'a':15,'b':'jn','c':54},'course':{'d':54,'e':65,'f':97},'kkoj':[654,677,647],'jhfuidh':(97,57,6887,547) ,'kiu':87516,'kjuhs':{4,5,546,89} }

# %%
l1=[]
for i in dict1.values():
  if type(i)==str:
    continue
  if type(i)==int:
    l1.append(i)
  elif type(i)==dict:
    for j in i.values():
      if type(j)==str:
        pass
      elif int or float or complex:
        l1.append(j.real)
  elif type(i)== list or tuple or set:
    for j in i:
      if type(j)==int or float or complex:
        l1.append(j.real)
max(l1)
# Out:
# 87516

# %%
for i in dict1:
  print(type(dict1[i]))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'list'>
# <class 'tuple'>
# <class 'str'>
# <class 'int'>
# <class 'set'>
