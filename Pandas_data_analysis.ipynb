# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Here age and cabin have less values (having NULL or NaN values), we need to handle those

# %%
data.describe() # this provides the statistics of numeric data type columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
for i in data.dtypes:
    print(i)
# Out:
# int64
# int64
# int64
# object
# object
# float64
# int64
# int64
# object
# float64
# object
# object

# %%
data.dtypes[data.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
type(data.dtypes[data.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
data.dtypes[data.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(data.dtypes[data.dtypes == 'object'].index)
# Out:
# pandas.core.indexes.base.Index

# %%
col_name = data.dtypes[data.dtypes == 'object'].index

# %%
data[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[col_name].describe() # after filtering the non-numeric columns , 
                        #we can check decsribe dataset,
                        #we get data statistics w.r.t object data
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['bhargav']='bhar'

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Name'][0:12]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
ind = data[data['Age'].isnull() == True].index

# %%
len(data[data['Age'].isnull() == True].index)
# Out:
# 177

# %% [markdown]
# how to get the complete record of the any of the index of above index which we fetched

# %%
data.loc[ind] # lock
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data[data['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data[data['Age']=='NaN'] # not works
# Null is different than 'NaN'
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, bhargav]
# Index: []

# %%
data['Fare'].max()
# Out:
# 512.3292

# %%
max(data['Fare'])
# Out:
# 512.3292

# %%
data[data['Fare'] == max(data["Fare"])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 1. Find out how many male and female passengers are boarded
# 2. How many persons are survived
# 3. How many causlities we had
# 4. what ishe name of a person who is the eldest one
# 5. how many passengers do we have in first and second and third class
# 6. how many person we have whose name strats with 's'
# 7. try to create a new column whuch is a summation of 'SibSp' and 'parch'
# 8. hoe many person do we have below age of 25
# 9. how many person died whose age was less than 40
# 10. From a cabin column separate text and numeric value

# %% [markdown]
# # 1. Find out how many male and female passengers are boarded

# %%
len(data[data['Sex']=='male'])
# Out:
# 577

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked  bhargav
# Sex
# female     97       312      314
# male      107       577      577

# %%
data.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %% [markdown]
# # 2. How many persons are survived

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
len(data[data['Survived']==1])
# Out:
# 342

# %% [markdown]
# # 3. How many causlities we had

# %%
len(data[data['Survived']==0])
# Out:
# 549

# %% [markdown]
# # 4. what ishe name of a person who is the eldest one

# %%
data[data['Age'].max()==data['Age']]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# # 5. how many passengers do we have in first and second and third class

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# # 6. how many person we have whose name strats with 's'

# %%
data[data['Name'].str.startswith('S')]['Name']
# Out:
# 10                       Sandstrom, Miss. Marguerite Rut
# 12                        Saundercock, Mr. William Henry
# 23                          Sloper, Mr. William Thompson
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 48                                   Samaan, Mr. Youssef
#                              ...
# 851                                  Svensson, Mr. Johan
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863                    Sage, Miss. Dorothy Edith "Dolly"
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 884                               Sutehall, Mr. Henry Jr
# Name: Name, Length: 86, dtype: object

# %%
data[data['Name'].str.startswith('S')]['Name'].count()
# Out:
# 86

# %%
len(data[data['Name'].str.startswith('S')])
# Out:
# 86

# %% [markdown]
# # 7. try to create a new column whuch is a summation of 'SibSp' and 'parch'

# %%
data['sum'] = data['SibSp']+data['Parch']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 8. hoe many person do we have below age of 25

# %%
len(data[data['Age']<25])
# Out:
# 278

# %% [markdown]
# # 9. how many person died whose age was less than 40

# %%
(data['Survived']==0) & (data['Age']<40)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
data[(data['Survived'] == 0) & (data['Age']<40)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# ...

# %%
len(data[(data['Survived'] == 0) & (data['Age']<40)])
# Out:
# 322

# %% [markdown]
# # 10. From a cabin column separate text and numeric value

# %%
import re
replace = re.compile("([a-zA-Z]+)")

data['cabin_str'] = data['Cabin'].str.extract(replace)
data['cabin_num'] = data['Cabin'].str.replace(replace,"")

# %%
data['cabin_str']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: cabin_str, Length: 891, dtype: object

# %%
data['cabin_num']
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: cabin_num, Length: 891, dtype: object

# %% [markdown]
# download & Read all resume from ineuron git in pdf, word and try to create a dataframe with resume as a index value, and columns emailid, linkdin id, git id, skills

# %% [markdown]
# # bank dataset

# %%
df1 = pd.read_csv(r'C:\Users\bharg\PycharmProjects\jupyter\bank\bank.csv', sep = ';') # bank marketing dataset UCI dataset

# %%
pd.read_csv(r'C:\Users\bharg\PycharmProjects\jupyter\bank\bank.csv', sep = ';') # bank marketing dataset UCI dataset
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# 1. how many campaign available in this data set
# 2. how many users do we have with housing and personal loan
# 3. how many person do we have whose age is 60+
# 4. in which month we have targeted most of the customer
# 5. which mode of call is giving you more result
# 6. how many enterprenuer do we have in this list
# 7. how many customers do we have with negative balance
# 8. prepare a group of data based on the education level

# %%
df1['campaign']
# Out:
# 0        1
# 1        1
# 2        1
# 3        4
# 4        1
#         ..
# 4516     5
# 4517     1
# 4518    11
# 4519     4
# 4520     2
# Name: campaign, Length: 4521, dtype: int64

# %%
df1['campaign'].unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
len(df1['campaign'].unique())
# Out:
# 32

# %%
len(df1[(df1['housing'] == 'yes') & (df1['loan']=='yes')])
# Out:
# 406

# %%
len(df1[df1['age']>60])
# Out:
# 127

# %%
df1['month'].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
df1['month'].value_counts().max()
# Out:
# 1398

# %%
max(df1['month'].value_counts())
# Out:
# 1398

# %%
df1['month'].value_counts().index
# Out:
# Index(['may', 'jul', 'aug', 'jun', 'nov', 'apr', 'feb', 'jan', 'oct', 'sep',
#        'mar', 'dec'],
#       dtype='object')

# %%
df1['month'].value_counts().index[0]
# Out:
# 'may'

# %%
df1.groupby(['contact','y']).count()
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
df_groupby = df1.groupby(['contact','y']).count()

# %%
df_groupby.loc['cellular','yes'][0]
# Out:
# 416

# %%
df_groupby.loc['telephone','yes'][0]
# Out:
# 44

# %%
df_groupby.loc['unknown','yes'][0]
# Out:
# 61

# %%
max(df_groupby.loc['cellular','yes'][0],df_groupby.loc['telephone','yes'][0],df_groupby.loc['unknown','yes'][0])
# Out:
# 416

# %%
len(df1[df1['job']=='entrepreneur'])
# Out:
# 168

# %%
len(df1[df1['balance']<0])
# Out:
# 366

# %%
df1[df1.balance <0]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 9      43       services   married    primary      no      -88     yes  yes
# 18     25    blue-collar    single    primary      no     -221     yes   no
# 48     32   entrepreneur    single    primary     yes     -849     yes  yes
# 60     41    blue-collar   married    primary      no     -516      no  yes
# 92     27       services    single  secondary      no     -195     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4474   44    blue-collar   married    primary      no     -237     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
#
# ...

# %%
l=[]
for i in df1['education'].unique():
    l.append(df1[df1['education'] == i])

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...
