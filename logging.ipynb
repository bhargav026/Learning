# %% [markdown]
# Logging

# %%
print('hygfs  bfsd mnkjfvwe')
# Out:
# hygfs  bfsd mnkjfvwe

# %%
import logging

# %%
logging.basicConfig(filename="test.log",level=logging.INFO)

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
logging.info('thid is my info log')
logging.warning('this is my waring log')
logging.error('this is my error my log')
# Out:
# WARNING:root:this is my waring log
# ERROR:root:this is my error my log

# %%
logging.shutdown()

# %% [markdown]
# DEBUG
# INFO
# WARNING
# ERROR
# CRITICAL

# %%
logging.basicConfig(filename='test2.log',level=logging.DEBUG, format='%(asctime)s %(levelname)s %(message)s')

# %%
logging.info('thid is my info log')
logging.warning('this is my waring log')
logging.error('this is my error my log')
logging.debug('this is debug log')
# Out:
# WARNING:root:this is my waring log
# ERROR:root:this is my error my log

# %%
logging.shutdown()

# %%
ERROR having top priority
WARNING
INFO
DEBUG lowest priority
# Out:
#   File "<ipython-input-24-e9e2752bdeaa>", line 1
#     ERROR having top priority
#                ^
# SyntaxError: invalid syntax

# %%
import logging
logging.basicConfig(filename = 'test3.log',level = logging.DEBUG, format='%(asctime)s %(levelname)s %(message)s')

# %%
def divbyzero(a,b):
  logging.info('this is a strst of my code and i am try to enter %s and %s',a,b)
  try:
    div=a/b
    logging.info('executed sucessfully')
  except Exception as e:
    logging.error('Error has happened')
    logging.warning('error is:'+str(e))

# %%
divbyzero(4,6)

# %%
logging.shutdown()
